# %%
from RFC import *


def config_help():
    project_config_example = get_config('project')
    project_config_example.print()
    # itemset_config_example = get_config('rawitemset')
    # itemset_config_example.print()
    # arguments_config_example = get_config('arguments-noproxy')
    # arguments_config_example.print()
    aiohttp_session_config_example = get_config('aiohttp')
    aiohttp_session_config_example.print(include_sub=False)
    requestor_config_exmaple = get_config('requestor')
    requestor_config_exmaple.print(include_sub=False)


config_help()
# Out:
# [2023-04-26 22:37:45] [INFO]
# ProjectConfig
# {
#     "debug": false,
#     "name": "<anonymous>",
#     "project_debug_log_path": "./project_debug.log",
#     "project_info_path": "./project_info.json",
#     "project_name": "<unknown>",
#     "project_run_log_path": "./project_run.log"
# }
# [2023-04-26 22:37:45] [INFO]
# AioHTTPSessionConfig
# {
#     "async_framework": "asyncio",
#     "connect_timeout": null,
#     "connections": 1,
#     "connections_per_host": 0,
#     "contiguous_failed_counts_threshold": null,
#     "framework": "aiohttp",
#     "name": "<anonymous>",
#     "sock_connect_timeout": null,
#     "sock_read_timeout": null,
#     "total_timeout": null,
#     "use_async": true,
#     "use_session": true
# }
# [2023-04-26 22:37:45] [INFO]
# RequestorConfig
# {
#     "name": "<anonymous>"
# }

# %%
def initialize_project():
    log('initializing project...\n', mode='info', from_module=__name__)
    def get_project_config():
        project_config = get_config('project')
        project_config = project_config(
            debug=True,
            name='MyProject',
            project_debug_log_path="./project_debug.log",
            project_info_path="./project_info.json",
            project_name="MyFirstProject",
            project_run_log_path="./project_run.log",
        )
        project_config.print()
        return project_config

    project_config = get_project_config()
    launch_project(project_config)

initialize_project()
# Out:
# [2023-04-26 22:37:51] [INFO] initializing project...
#
# [2023-04-26 22:37:51] [INFO]
# ProjectConfig
# {
#     "debug": true,
#     "name": "MyProject",
#     "project_debug_log_path": "./project_debug.log",
#     "project_info_path": "./project_info.json",
#     "project_name": "MyFirstProject",
#     "project_run_log_path": "./project_run.log"
# }
# [2023-04-26 22:37:51] (Project) [INFO] Project MyFirstProject launched.
#
# Project Configurations:
# {
#     "debug": true,
#     "name": "MyProject",
#     "project_debug_log_path": "./project_debug.log",
#     "project_info_path": "./project_info.json",
#     "project_name": "MyFirstProject",
#     "project_root": "/remote-home/qhgao/Workspace/Datasets/Crawlers/TMP/workdir/MyFirstProject",
#     "project_run_log_path": "./project_run.log"
# }

# %%
def get_itemset():
    log('initializing itemset...\n', mode='info', from_module=__name__)
    def get_itemset_config():
        itemset_config = get_config('rawitemset')
        itemset_config = itemset_config(
            name='MyItemset',
            items=list(range(200000, 210000)),
            preprocess=None,
            attrs={
                'url': lambda i, x: f'https://www.pixiv.net/ajax/illust/{x}',
                'method': 'get',
                'name': lambda i, x: f'illust_{x}',
            },
            shuffle=True,
        )
        return itemset_config

    itemset_config = get_itemset_config()
    itemset = get_module(itemset_config)
    itemset.show()
    return itemset


itemset = get_itemset()
# Out:
# [2023-04-26 21:51:27] [INFO] initializing itemset...
#
# RawItem(name='illust_202587', url='https://www.pixiv.net/ajax/illust/202587', payload={}, params={}, method='get')
# RawItem(name='illust_200526', url='https://www.pixiv.net/ajax/illust/200526', payload={}, params={}, method='get')
# RawItem(name='illust_202568', url='https://www.pixiv.net/ajax/illust/202568', payload={}, params={}, method='get')
# RawItem(name='illust_209119', url='https://www.pixiv.net/ajax/illust/209119', payload={}, params={}, method='get')
# RawItem(name='illust_202472', url='https://www.pixiv.net/ajax/illust/202472', payload={}, params={}, method='get')
# RawItem(name='illust_205382', url='https://www.pixiv.net/ajax/illust/205382', payload={}, params={}, method='get')
# RawItem(name='illust_202367', url='https://www.pixiv.net/ajax/illust/202367', payload={}, params={}, method='get')
# RawItem(name='illust_207004', url='https://www.pixiv.net/ajax/illust/207004', payload={}, params={}, method='get')
# RawItem(name='illust_208994', url='https://www.pixiv.net/ajax/illust/208994', payload={}, params={}, method='get')
# RawItem(name='illust_201820', url='https://www.pixiv.net/ajax/illust/201820', payload={}, params={}, method='get')

# %%
def get_session():
    log('initializing session...\n', mode='info', from_module=__name__)

    def get_arguments_config():
        arguments_config = get_config('arguments-noproxy')
        arguments_config = arguments_config(
            name='MyArguments',
        )
        arguments_config.show()
        return arguments_config

    def get_session_config():
        session_config = get_config('aiohttp')
        session_config = session_config(
            name='MySession',
            arguments_config=get_arguments_config(),
            total_timeout=20,
            connections=10,
            connections_per_host=10,
        )
        return session_config

    session_config = get_session_config()
    session = get_module(session_config)
    session.print()
    return session


session = get_session()
# Out:
# [2023-04-26 21:51:28] [INFO] initializing session...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 28
#      24     session.print()
#      25     return session
# ---> 28 session = get_session()
#
# Cell In[3], line 23, in get_session()
#      20     return session_config
#      22 session_config = get_session_config()
# ---> 23 session = get_module(session_config)
#      24 session.print()
#      25 return session
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/user/user.py:123, in get_module(module_config)
#     121     module = get_requestor(module_config)
#     122 elif 'SessionConfig' in module_name:
# --> 123     module = get_session(module_config)
#     124 elif 'ArgumentsConfig' in module_name:
#     125     module = get_arguments(module_config)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/utils/structural_utils.py:69, in return_decorated_func.<locals>.inner_func(*args, **kwargs)
#      67 @functools.wraps(func)
#      68 def inner_func(*args, **kwargs):
# ---> 69     return func(*args, **kwargs)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/session.py:64, in get_session(session_config, **kwargs)
#      62     return AsksSession(session_config, **kwargs)
#      63 elif session_type == 'aiohttp':
# ---> 64     return AioHTTPSession(session_config, **kwargs)
#      65 else:
#      66     raise ConditionOverflowError(session_type, __name__)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/AioHTTPSession.py:43, in AioHTTPSession.__init__(self, session_config)
#      39 def __init__(
#      40     self,
#      41     session_config: AioHTTPSessionConfig,
#      42 ):
# ---> 43     super().__init__(session_config)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/Session.py:44, in Session.__init__(self, session_config)
#      40 def __init__(
#      41     self,
#      42     session_config: SessionConfig,
#      43 ):
# ---> 44     super().__init__(session_config)
#      45     ...
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/BaseSession.py:61, in BaseSession.__init__(self, session_config)
#      59 self.name = self.session_config.name
#      60 self.use_session = self.session_config.use_session
# ---> 61 self._init_all()
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/BaseSession.py:50, in BaseSession._init_all(self)
#      48 self._init_arguments()
#      49 self._init_attrs()
# ---> 50 self._init_session_args()
#      51 self._init_request_args()
#      52 self._init_states()
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/AioHTTPSession.py:33, in AioHTTPSession._init_session_args(self)
#      28 self.session_only_args = ['headers', 'cookies']
#      29 self.session_common_args = {
#      30     'connector': self.connector,
#      31     'timeout': self.timeout,
#      32 }
# ---> 33 request_args = self.arguments(include=self.session_only_args)
#      34 request_args.update(self.session_common_args)
#      35 self.session = aiohttp.Session(
#      36     **request_args
#      37 )
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/arguments/BaseArguments.py:91, in BaseArguments.__call__(self, **kwargs)
#      87 def __call__(
#      88     self,
#      89     **kwargs,
#      90 ):
# ---> 91     return self._get_request_params(**kwargs)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/arguments/BaseArguments.py:80, in BaseArguments._get_request_params(self, url, payload, include, exclude, rename_map, **kwargs)
#      78 if self.arguments_partial is None:
#      79     self._get_arguments_partial()
# ---> 80 arguments = self.arguments_partial(include=include, exclude=exclude, url=url, payload=payload, **kwargs)
#      81 for name in rename_map:
#      82     if name in arguments:
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/arguments/BaseArguments.py:63, in BaseArguments._get_arguments_partial.<locals>.arguments_wrapper(arguments_partial, include, exclude, url, payload, **kwargs)
#      62 def arguments_wrapper(arguments_partial, include, exclude, url=None, payload=None, **kwargs):
# ---> 63     arguments = self._traverse_arguments_partial({name: value for name, value in arguments_partial.items() if check_restriction(name, include, exclude)}, url=url, payload=payload, **kwargs)
#      64     return arguments
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/arguments/BaseArguments.py:54, in BaseArguments._traverse_arguments_partial(self, arguments_partial, url, payload, **kwargs)
#      52 for argument_name in arguments_partial:
#      53     if isinstance(arguments_partial[argument_name], partial):
# ---> 54         arguments[argument_name] = arguments_partial[argument_name](url=url, payload=payload, **kwargs)
#      55     else:
#      56         arguments[argument_name] = self._traverse_arguments_partial(arguments_partial[argument_name], url=url, payload=payload, **kwargs)
#
# TypeError: passin() missing 1 required positional argument: 'cookies'

# %%
def get_requestor():
    

    def get_session_config():
        ...

    def get_requestor_config():
        ...
    
    requestor_config = get_requestor_config()
    requestor_config.print()
    requestor = get_module(requestor_config)
    return requestor


requestor = get_requestor()

# %%
# Convert .ipynb to .py
import os

if __name__ == '__main__':
    os.system('jupyter nbconvert --to python <your_notebook_name>.ipynb')
