# %%
from RFC import *


def config_help():
    project_config_example = get_config('project')
    project_config_example.print()
    # itemset_config_example = get_config('rawitemset')
    # itemset_config_example.print()
    # arguments_config_example = get_config('arguments-noproxy')
    # arguments_config_example.print()
    aiohttp_session_config_example = get_config('aiohttp')
    aiohttp_session_config_example.print(include_sub=False)
    requestor_config_exmaple = get_config('requestor')
    requestor_config_exmaple.print(include_sub=False)


config_help()
# Out:
# [2023-05-09 19:02:24] [INFO]
# ProjectConfig
# {
#     "_debug": false,
#     "_name": "<anonymous>",
#     "_project_config_path": "./configs",
#     "_project_debug_log_path": "./project_debug.log",
#     "_project_info_path": "./project_info.json",
#     "_project_log_path": "./logs",
#     "_project_name": "<unknown>",
#     "_project_raw_path": "./raw",
#     "_project_result_path": "./saves",
#     "_project_run_log_path": "./project_run.log"
# }
# [2023-05-09 19:02:24] [INFO]
# AioHTTPSessionConfig
# {
#     "_async_framework": "asyncio",
#     "_connect_timeout": null,
#     "_connections": 1,
#     "_connections_per_host": 0,
#     "_contiguous_failed_counts_threshold": null,
#     "_framework": "aiohttp",
#     "_name": "<anonymous>",
#     "_sock_connect_timeout": null,
#     "_sock_read_timeout": null,
#     "_total_timeout": null,
#     "_use_async": true,
#     "_use_session": true
# }
# [2023-05-09 19:02:24] [INFO]
# RequestorConfig
# {
#     "_name": "<anonymous>"
# }

# %%
def initialize_project():
    log('initializing project...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)
    def get_project_config():
        project_config = get_config('project')
        project_config = project_config(
            debug=True,
            name='MyProject',
            project_debug_log_path="./project_debug.log",
            project_info_path="./project_info.json",
            project_name="MyFirstProject",
            project_run_log_path="./project_run.log",
        )
        project_config.print()
        return project_config

    project_config = get_project_config()
    launch_project(project_config)

initialize_project()
# Out:
# [2023-05-09 19:02:24] (Pipeline) [INFO] initializing project...
#
# [2023-05-09 19:02:24] [INFO]
# ProjectConfig
# {
#     "_debug": true,
#     "_name": "MyProject",
#     "_project_config_path": "./configs",
#     "_project_debug_log_path": "./project_debug.log",
#     "_project_info_path": "./project_info.json",
#     "_project_log_path": "./logs",
#     "_project_name": "MyFirstProject",
#     "_project_raw_path": "./raw",
#     "_project_result_path": "./saves",
#     "_project_run_log_path": "./project_run.log"
# }
#
#
# checking integrity...
#
# [2023-05-09 19:02:24] [INFO] custom __init__.py for path 'RFC'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/itemset'
# [2023-05-09 19:02:24] [INFO] custom __init__.py for path 'RFC/user'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/params'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/payload'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/proxies'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/url'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/user-agent'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/base'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/referer'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/cookies'
# [2023-05-09 19:02:24] [INFO] system predefined __init__.py for path 'RFC/requestor/session/middleware'
#
# Done.
#
# compiling modules...
#
#
# Done.

# %%
def get_itemset():
    log('initializing itemset...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)
    def get_itemset_config():
        itemset_config = get_config('rawitemset')
        itemset_config = itemset_config(
            name='MyItemset',
            items=list(range(200000, 210000)),
            preprocess=None,
            attrs={
                'url': lambda i, x: f'https://www.pixiv.net/ajax/illust/{x}',
                'method': 'get',
                'name': lambda i, x: f'illust_{x}',
            },
            shuffle=True,
        )
        return itemset_config

    itemset_config = get_itemset_config()
    itemset = get_module(itemset_config)
    itemset.show()
    return itemset


itemset = get_itemset()
# Out:
# [2023-05-09 19:02:26] (Pipeline) [INFO] initializing itemset...
#
# {'url': 'https://www.pixiv.net/ajax/illust/208791', 'method': 'get', 'name': 'illust_208791', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/208285', 'method': 'get', 'name': 'illust_208285', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/204024', 'method': 'get', 'name': 'illust_204024', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/205304', 'method': 'get', 'name': 'illust_205304', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/200044', 'method': 'get', 'name': 'illust_200044', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/206415', 'method': 'get', 'name': 'illust_206415', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/205776', 'method': 'get', 'name': 'illust_205776', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/209098', 'method': 'get', 'name': 'illust_209098', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/201492', 'method': 'get', 'name': 'illust_201492', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/202206', 'method': 'get', 'name': 'illust_202206', 'return_type': ['resp']}

# %%
def get_requestor():
    log('initializing requestor...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)

    def get_arguments_config():
        arguments_config = get_config('arguments-noproxy')
        arguments_config = arguments_config(
            name='MyArguments',
            config={
                'cookies': {
                    'kwargs': {
                        'cookies': {
                            'PHPSESSID': '1234567890abcdef1234567890abcdef',
                            'device_token': '1234567890abcdef1234567890abcdef',
                        },
                        'ctype': dict,
                    },
                    'method': 'passin',
                },
            },
        )
        # arguments_config.print()
        return arguments_config

    def get_session_config():
        session_config = get_config('aiohttp')
        session_config = session_config(
            name='MySession',
            arguments_config=get_arguments_config(),
            total_timeout=20,
            connections=10,
            connections_per_host=10,
        )
        # session_config.print(include_sub=True)
        return session_config

    def get_requestor_config():
        requestor_config = get_config('requestor')
        requestor_config = requestor_config(
            name='MyRequestor',
            session_config=get_session_config(),
        )
        requestor_config.print(include_sub=True)
        return requestor_config

    requstor_config = get_requestor_config()
    requestor = get_module(requstor_config)
    return requestor


requestor = get_requestor()
# Out:
# [2023-05-09 19:02:26] (Pipeline) [INFO] initializing requestor...
#
# [2023-05-09 19:02:26] [INFO]
# RequestorConfig
# {
#     "_name": "MyRequestor",
#     "_session_config": {
#         "_arguments_config": {
#             "_config": {
#                 "cookies": {
#                     "kwargs": {
#                         "cookies": {
#                             "PHPSESSID": "1234567890abcdef1234567890abcdef",
#                             "device_token": "1234567890abcdef1234567890abcdef"
#                         },
#                         "ctype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "headers": {
#                     "base": {
#                         "kwargs": {
#                             "option": "default"
#                         },
#                         "method": "switch"
#                     },
#                     "kwargs": {},
#                     "referer": {
#                         "kwargs": {},
#                         "method": "from_url"
#                     },
#                     "user-agent": {
#                         "kwargs": {
#                             "type": "firefox"
#                         },
#                         "method": "random_fake"
#                     }
#                 },
#                 "kwargs": {},
#                 "params": {
#                     "kwargs": {
#                         "ptype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "payload": {
#                     "kwargs": {
#                         "ptype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "proxies": {
#                     "kwargs": {},
#                     "method": "off"
#                 },
#                 "url": {
#                     "kwargs": {},
#                     "method": "passin"
#                 }
#             },
#             "_name": "MyArguments"
#         },
#         "_async_framework": "asyncio",
#         "_connect_timeout": null,
#         "_connections": 10,
#         "_connections_per_host": 10,
#         "_contiguous_failed_counts_threshold": null,
#         "_framework": "aiohttp",
#         "_name": "MySession",
#         "_sock_connect_timeout": null,
#         "_sock_read_timeout": null,
#         "_total_timeout": 20,
#         "_use_async": true,
#         "_use_session": true
#     }
# }

# %%
# Convert .ipynb to .py
import os

if __name__ == '__main__':
    pass
    # os.system('jupyter nbconvert --to python test_RFC_modules.ipynb')
# Out:
# [NbConvertApp] Converting notebook test_RFC_pipeline.ipynb to python
# [NbConvertApp] Writing 3891 bytes to test_RFC_pipeline.py
