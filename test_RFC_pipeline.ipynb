# %%
from RFC import *


def config_help():
    project_config_example = get_config('project')
    project_config_example.print()
    # itemset_config_example = get_config('rawitemset')
    # itemset_config_example.print()
    # arguments_config_example = get_config('arguments-noproxy')
    # arguments_config_example.print()
    aiohttp_session_config_example = get_config('aiohttp')
    aiohttp_session_config_example.print(include_sub=False)
    requestor_config_exmaple = get_config('requestor')
    requestor_config_exmaple.print(include_sub=False)


config_help()
# Out:
# [2023-05-09 17:15:12] [INFO]
# ProjectConfig
# {
#     "_debug": false,
#     "_name": "<property object at 0x7f12c425eac0>",
#     "_project_config_path": "./configs",
#     "_project_debug_log_path": "./project_debug.log",
#     "_project_info_path": "./project_info.json",
#     "_project_log_path": "./logs",
#     "_project_name": "<unknown>",
#     "_project_raw_path": "/raw",
#     "_project_result_path": "./saves",
#     "_project_run_log_path": "./project_run.log"
# }
# [2023-05-09 17:15:12] [INFO]
# AioHTTPSessionConfig
# {
#     "_arguments_config": "<property object at 0x7f12c41b8db0>",
#     "_async_framework": "asyncio",
#     "_connect_timeout": null,
#     "_connections": 1,
#     "_connections_per_host": 0,
#     "_contiguous_failed_counts_threshold": "<property object at 0x7f12c41b8ea0>",
#     "_framework": "aiohttp",
#     "_name": "<property object at 0x7f12c425eac0>",
#     "_sock_connect_timeout": null,
#     "_sock_read_timeout": null,
#     "_total_timeout": null,
#     "_use_async": true,
#     "_use_session": "<property object at 0x7f12c41b8ef0>"
# }
# [2023-05-09 17:15:12] [INFO]
# RequestorConfig
# {
#     "_name": "<property object at 0x7f12c425eac0>"
# }

# %%
def initialize_project():
    log('initializing project...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)
    def get_project_config():
        project_config = get_config('project')
        project_config = project_config(
            debug=True,
            name='MyProject',
            project_debug_log_path="./project_debug.log",
            project_info_path="./project_info.json",
            project_name="MyFirstProject",
            project_run_log_path="./project_run.log",
        )
        project_config.print()
        return project_config

    project_config = get_project_config()
    launch_project(project_config)

initialize_project()
# Out:
# [2023-05-09 17:16:43] (Pipeline) [INFO] initializing project...
#
# [2023-05-09 17:16:43] [INFO]
# ProjectConfig
# {
#     "_debug": false,
#     "_name": "<property object at 0x7f12c425eac0>",
#     "_project_config_path": "./configs",
#     "_project_debug_log_path": "./project_debug.log",
#     "_project_info_path": "./project_info.json",
#     "_project_log_path": "./logs",
#     "_project_name": "<unknown>",
#     "_project_raw_path": "/raw",
#     "_project_result_path": "./saves",
#     "_project_run_log_path": "./project_run.log",
#     "debug": true,
#     "name": "MyProject",
#     "project_debug_log_path": "./project_debug.log",
#     "project_info_path": "./project_info.json",
#     "project_name": "MyFirstProject",
#     "project_run_log_path": "./project_run.log"
# }
#
#
# checking integrity...
#
# [2023-05-09 17:16:43] [INFO] custom __init__.py for path 'RFC'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/itemset'
# [2023-05-09 17:16:43] [INFO] custom __init__.py for path 'RFC/user'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/params'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/payload'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/proxies'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/url'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/user-agent'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/base'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/referer'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/cookies'
# [2023-05-09 17:16:43] [INFO] system predefined __init__.py for path 'RFC/requestor/session/middleware'
#
# Done.
#
# compiling modules...
#
#
# Done.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 20
#      17     launch_project(project_config)
#      19 initialize_project()
# ---> 20 project_config
#
# NameError: name 'project_config' is not defined

# %%
def get_itemset():
    log('initializing itemset...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)
    def get_itemset_config():
        itemset_config = get_config('rawitemset')
        itemset_config = itemset_config(
            name='MyItemset',
            items=list(range(200000, 210000)),
            preprocess=None,
            attrs={
                'url': lambda i, x: f'https://www.pixiv.net/ajax/illust/{x}',
                'method': 'get',
                'name': lambda i, x: f'illust_{x}',
            },
            shuffle=True,
        )
        return itemset_config

    itemset_config = get_itemset_config()
    itemset = get_module(itemset_config)
    itemset.show()
    return itemset


itemset = get_itemset()
# Out:
# [2023-05-09 17:15:13] (Pipeline) [INFO] initializing itemset...
# ---------------------------------------------------------------------------
# ParamSettingError                         Traceback (most recent call last)
# Cell In[3], line 24
#      20     itemset.show()
#      21     return itemset
# ---> 24 itemset = get_itemset()
#
# Cell In[3], line 19, in get_itemset()
#      16     return itemset_config
#      18 itemset_config = get_itemset_config()
# ---> 19 itemset = get_module(itemset_config)
#      20 itemset.show()
#      21 return itemset
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/user/user.py:119, in get_module(module_config)
#     117 module_name = type(module_config).__name__
#     118 if 'ItemsetConfig' in module_name:
# --> 119     module = get_itemset(module_config)
#     120 elif 'RequestorConfig' in module_name:
#     121     module = get_requestor(module_config)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/utils/structural_utils.py:69, in return_decorated_func.<locals>.inner_func(*args, **kwargs)
#      67 @functools.wraps(func)
#      68 def inner_func(*args, **kwargs):
# ---> 69     return func(*args, **kwargs)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/itemset/itemset.py:52, in get_itemset(itemset_config, **kwargs)
#      50     raise ParamValueError('itemset_type', itemset_type, all_supported_itemsets, __name__)
#      51 if itemset_type == 'raw':
# ---> 52     return RawItemset(itemset_config)
#      53 elif itemset_type == 'default':
#      54     return Itemset(itemset_config)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/itemset/RawItemset.py:20, in RawItemset.__init__(self, itemset_config)
#      16 def __init__(
#      17     self,
#      18     itemset_config: RawItemsetConfig,
#      19 ):
# ---> 20     super().__init__(itemset_config)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/itemset/Itemset.py:20, in Itemset.__init__(self, itemset_config)
#      16 def __init__(
#      17     self,
#      18     itemset_config: ItemsetConfig,
#      19 ):
# ---> 20     super().__init__(itemset_config)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/itemset/BaseItemset.py:101, in BaseItemset.__init__(self, itemset_config)
#      99 self.name = self.itemset_config.name
#     100 self.init_items(itemset_config.items, itemset_config.preprocess, itemset_config.shuffle)
# --> 101 self.init_all_attrs(itemset_config.attrs)
#     102 self.convert2item()
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/itemset/BaseItemset.py:62, in BaseItemset.init_all_attrs(self, attrs)
#      60 self.attrs = {}
#      61 if 'url' not in attrs:
# ---> 62     raise ParamSettingError("Param 'url' is required", __name__, attrs=attrs)
#      63 if 'method' not in attrs:
#      64     raise ParamSettingError("Param 'method' is required", __name__, attrs=attrs)
#
# ParamSettingError: Incorrect params setting <attrs={}>. Param 'url' is required. Error raised from RFC.itemset.BaseItemset.

# %%
def get_requestor():
    log('initializing requestor...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)

    def get_arguments_config():
        arguments_config = get_config('arguments-noproxy')
        arguments_config = arguments_config(
            name='MyArguments',
            config={
                'cookies': {
                    'kwargs': {
                        'cookies': {
                            'PHPSESSID': '1234567890abcdef1234567890abcdef',
                            'device_token': '1234567890abcdef1234567890abcdef',
                        },
                        'ctype': dict,
                    },
                    'method': 'passin',
                },
            },
        )
        # arguments_config.print()
        return arguments_config

    def get_session_config():
        session_config = get_config('aiohttp')
        session_config = session_config(
            name='MySession',
            arguments_config=get_arguments_config(),
            total_timeout=20,
            connections=10,
            connections_per_host=10,
        )
        # session_config.print(include_sub=True)
        return session_config

    def get_requestor_config():
        requestor_config = get_config('requestor')
        requestor_config = requestor_config(
            name='MyRequestor',
            session_config=get_session_config(),
        )
        requestor_config.print(include_sub=True)
        return requestor_config

    requstor_config = get_requestor_config()
    requestor = get_module(requstor_config)
    return requestor


requestor = get_requestor()
# Out:
# [2023-05-09 16:37:31] (Pipeline) [INFO] initializing requestor...
#
# [2023-05-09 16:37:31] [INFO]
# RequestorConfig
# {
#     "_name": "<anonymous>",
#     "name": "MyRequestor",
#     "session_config": {
#         "_name": "<anonymous>",
#         "arguments_config": {
#             "_name": "<anonymous>",
#             "config": {
#                 "cookies": {
#                     "kwargs": {
#                         "cookies": {
#                             "PHPSESSID": "1234567890abcdef1234567890abcdef",
#                             "device_token": "1234567890abcdef1234567890abcdef"
#                         },
#                         "ctype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "headers": {
#                     "base": {
#                         "kwargs": {
#                             "option": "default"
#                         },
#                         "method": "switch"
#                     },
#                     "kwargs": {},
#                     "referer": {
#                         "kwargs": {},
#                         "method": "from_url"
#                     },
#                     "user-agent": {
#                         "kwargs": {
#                             "type": "firefox"
#                         },
#                         "method": "random_fake"
#                     }
#                 },
#                 "kwargs": {},
#                 "params": {
#                     "kwargs": {
#                         "ptype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "payload": {
#                     "kwargs": {
#                         "ptype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "proxies": {
#                     "kwargs": {},
#                     "method": "off"
#                 },
#                 "url": {
#                     "kwargs": {},
#                     "method": "passin"
#                 }
#             },
#             "name": "MyArguments"
#         },
#         "async_framework": "asyncio",
#         "connect_timeout": null,
#         "connections": 10,
#         "connections_per_host": 10,
#         "contiguous_failed_counts_threshold": null,
#         "framework": "aiohttp",
#         "name": "MySession",
#         "sock_connect_timeout": null,
#         "sock_read_timeout": null,
#         "total_timeout": 20,
#         "use_async": true,
#         "use_session": true
#     }
# }

# %%
# Convert .ipynb to .py
import os

if __name__ == '__main__':
    os.system('jupyter nbconvert --to python test_RFC_pipeline.ipynb')
# Out:
# [NbConvertApp] Converting notebook test_RFC_pipeline.ipynb to python
# [NbConvertApp] Writing 3891 bytes to test_RFC_pipeline.py
