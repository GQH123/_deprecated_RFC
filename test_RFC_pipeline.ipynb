# %%
from RFC import *


def config_help():
    project_config_example = get_config('project')
    project_config_example.print()
    # itemset_config_example = get_config('rawitemset')
    # itemset_config_example.print()
    # arguments_config_example = get_config('arguments-noproxy')
    # arguments_config_example.print()
    aiohttp_session_config_example = get_config('aiohttp')
    aiohttp_session_config_example.print(include_sub=False)
    requestor_config_exmaple = get_config('requestor')
    requestor_config_exmaple.print(include_sub=False)


config_help()
# Out:
# [2023-05-09 15:33:36] [INFO]
# ProjectConfig
# {
#     "debug": false,
#     "name": "<anonymous>",
#     "project_config_path": "./configs",
#     "project_debug_log_path": "./project_debug.log",
#     "project_info_path": "./project_info.json",
#     "project_log_path": "./logs",
#     "project_name": "<unknown>",
#     "project_raw_path": "./raw",
#     "project_result_path": "./saves",
#     "project_run_log_path": "./project_run.log"
# }
# [2023-05-09 15:33:36] [INFO]
# AioHTTPSessionConfig
# {
#     "async_framework": "asyncio",
#     "connect_timeout": null,
#     "connections": 1,
#     "connections_per_host": 0,
#     "contiguous_failed_counts_threshold": null,
#     "framework": "aiohttp",
#     "name": "<anonymous>",
#     "sock_connect_timeout": null,
#     "sock_read_timeout": null,
#     "total_timeout": null,
#     "use_async": true,
#     "use_session": true
# }
# [2023-05-09 15:33:36] [INFO]
# RequestorConfig
# {
#     "name": "<anonymous>"
# }

# %%
def initialize_project():
    log('initializing project...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)
    def get_project_config():
        project_config = get_config('project')
        project_config = project_config(
            debug=True,
            name='MyProject',
            project_debug_log_path="./project_debug.log",
            project_info_path="./project_info.json",
            project_name="MyFirstProject",
            project_run_log_path="./project_run.log",
        )
        project_config.print()
        return project_config

    project_config = get_project_config()
    launch_project(project_config)

initialize_project()
# Out:
# [2023-05-09 15:33:37] (Pipeline) [INFO] initializing project...
#
# [2023-05-09 15:33:37] [INFO]
# ProjectConfig
# {
#     "debug": true,
#     "name": "MyProject",
#     "project_config_path": "./configs",
#     "project_debug_log_path": "./project_debug.log",
#     "project_info_path": "./project_info.json",
#     "project_log_path": "./logs",
#     "project_name": "MyFirstProject",
#     "project_raw_path": "./raw",
#     "project_result_path": "./saves",
#     "project_run_log_path": "./project_run.log"
# }
#
#
# checking integrity...
#
# [2023-05-09 15:33:37] [INFO] custom __init__.py for path 'RFC'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/itemset'
# [2023-05-09 15:33:37] [INFO] custom __init__.py for path 'RFC/user'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/params'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/payload'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/proxies'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/url'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/user-agent'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/base'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/referer'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/cookies'
# [2023-05-09 15:33:37] [INFO] system predefined __init__.py for path 'RFC/requestor/session/middleware'
#
# Done.
#
# compiling modules...
#
#
# Done.

# %%
def get_itemset():
    log('initializing itemset...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)
    def get_itemset_config():
        itemset_config = get_config('rawitemset')
        itemset_config = itemset_config(
            name='MyItemset',
            items=list(range(200000, 210000)),
            preprocess=None,
            attrs={
                'url': lambda i, x: f'https://www.pixiv.net/ajax/illust/{x}',
                'method': 'get',
                'name': lambda i, x: f'illust_{x}',
            },
            shuffle=True,
        )
        return itemset_config

    itemset_config = get_itemset_config()
    itemset = get_module(itemset_config)
    itemset.show()
    return itemset


itemset = get_itemset()
# Out:
# [2023-05-09 15:33:38] (Pipeline) [INFO] initializing itemset...
#
# {'url': 'https://www.pixiv.net/ajax/illust/209519', 'method': 'get', 'name': 'illust_209519', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/205375', 'method': 'get', 'name': 'illust_205375', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/208268', 'method': 'get', 'name': 'illust_208268', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/206120', 'method': 'get', 'name': 'illust_206120', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/205843', 'method': 'get', 'name': 'illust_205843', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/203039', 'method': 'get', 'name': 'illust_203039', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/200319', 'method': 'get', 'name': 'illust_200319', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/201353', 'method': 'get', 'name': 'illust_201353', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/204108', 'method': 'get', 'name': 'illust_204108', 'return_type': ['resp']}
# {'url': 'https://www.pixiv.net/ajax/illust/204549', 'method': 'get', 'name': 'illust_204549', 'return_type': ['resp']}

# %%
def get_requestor():
    log('initializing requestor...\n', file=['stdout'], mode='info', note='Pipeline', from_module=__name__)

    def get_arguments_config():
        arguments_config = get_config('arguments-noproxy')
        arguments_config = arguments_config(
            name='MyArguments',
            config={
                'cookies': {
                    'kwargs': {
                        'cookies': {
                            'PHPSESSID': '1234567890abcdef1234567890abcdef',
                            'device_token': '1234567890abcdef1234567890abcdef',
                        },
                        'ctype': dict,
                    },
                    'method': 'passin',
                },
            },
        )
        # arguments_config.print()
        return arguments_config

    def get_session_config():
        session_config = get_config('aiohttp')
        session_config = session_config(
            name='MySession',
            arguments_config=get_arguments_config(),
            total_timeout=20,
            connections=10,
            connections_per_host=10,
        )
        # session_config.print(include_sub=True)
        return session_config

    def get_requestor_config():
        requestor_config = get_config('requestor')
        requestor_config = requestor_config(
            name='MyRequestor',
            session_config=get_session_config(),
        )
        requestor_config.print(include_sub=True)
        return requestor_config

    requstor_config = get_requestor_config()
    requestor = get_module(requstor_config)
    return requestor


requestor = get_requestor()
# Out:
# [2023-05-09 15:33:39] (Pipeline) [INFO] initializing requestor...
#
# [2023-05-09 15:33:39] [INFO]
# RequestorConfig
# {
#     "name": "MyRequestor",
#     "session_config": {
#         "arguments_config": {
#             "config": {
#                 "cookies": {
#                     "kwargs": {
#                         "cookies": {
#                             "PHPSESSID": "1234567890abcdef1234567890abcdef",
#                             "device_token": "1234567890abcdef1234567890abcdef"
#                         },
#                         "ctype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "headers": {
#                     "base": {
#                         "kwargs": {
#                             "option": "default"
#                         },
#                         "method": "switch"
#                     },
#                     "kwargs": {},
#                     "referer": {
#                         "kwargs": {},
#                         "method": "from_url"
#                     },
#                     "user-agent": {
#                         "kwargs": {
#                             "type": "firefox"
#                         },
#                         "method": "random_fake"
#                     }
#                 },
#                 "kwargs": {},
#                 "params": {
#                     "kwargs": {
#                         "ptype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "payload": {
#                     "kwargs": {
#                         "ptype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "proxies": {
#                     "kwargs": {},
#                     "method": "off"
#                 },
#                 "url": {
#                     "kwargs": {},
#                     "method": "passin"
#                 }
#             },
#             "name": "MyArguments"
#         },
#         "async_framework": "asyncio",
#         "connect_timeout": null,
#         "connections": 10,
#         "connections_per_host": 10,
#         "contiguous_failed_counts_threshold": null,
#         "framework": "aiohttp",
#         "name": "MySession",
#         "sock_connect_timeout": null,
#         "sock_read_timeout": null,
#         "total_timeout": 20,
#         "use_async": true,
#         "use_session": true
#     }
# }

# %%
# Convert .ipynb to .py
import os

if __name__ == '__main__':
    os.system('jupyter nbconvert --to python test_RFC_pipeline.ipynb')
# Out:
# [NbConvertApp] Converting notebook test_RFC_pipeline.ipynb to python
# [NbConvertApp] Writing 3894 bytes to test_RFC_pipeline.py
