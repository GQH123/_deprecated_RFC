# %%
from RFC import *


def config_help():
    project_config_example = get_config('project')
    project_config_example.print()
    # itemset_config_example = get_config('rawitemset')
    # itemset_config_example.print()
    # arguments_config_example = get_config('arguments-noproxy')
    # arguments_config_example.print()
    aiohttp_session_config_example = get_config('aiohttp')
    aiohttp_session_config_example.print(include_sub=False)
    requestor_config_exmaple = get_config('requestor')
    requestor_config_exmaple.print(include_sub=False)


config_help()
# Out:
# [2023-05-08 09:15:29] [INFO]
# ProjectConfig
# {
#     "debug": false,
#     "name": "<anonymous>",
#     "project_debug_log_path": "./project_debug.log",
#     "project_info_path": "./project_info.json",
#     "project_name": "<unknown>",
#     "project_run_log_path": "./project_run.log"
# }
# [2023-05-08 09:15:29] [INFO]
# AioHTTPSessionConfig
# {
#     "async_framework": "asyncio",
#     "connect_timeout": null,
#     "connections": 1,
#     "connections_per_host": 0,
#     "contiguous_failed_counts_threshold": null,
#     "framework": "aiohttp",
#     "name": "<anonymous>",
#     "sock_connect_timeout": null,
#     "sock_read_timeout": null,
#     "total_timeout": null,
#     "use_async": true,
#     "use_session": true
# }
# [2023-05-08 09:15:29] [INFO]
# RequestorConfig
# {
#     "name": "<anonymous>"
# }

# %%
def initialize_project():
    log('initializing project...\n', mode='info', note='Pipeline', from_module=__name__)
    def get_project_config():
        project_config = get_config('project')
        project_config = project_config(
            debug=True,
            name='MyProject',
            project_debug_log_path="./project_debug.log",
            project_info_path="./project_info.json",
            project_name="MyFirstProject",
            project_run_log_path="./project_run.log",
        )
        project_config.print()
        return project_config

    project_config = get_project_config()
    launch_project(project_config)

initialize_project()
# Out:
# [2023-05-08 09:15:29] (Pipeline) [INFO] initializing project...
#
# [2023-05-08 09:15:29] [INFO]
# ProjectConfig
# {
#     "debug": true,
#     "name": "MyProject",
#     "project_debug_log_path": "./project_debug.log",
#     "project_info_path": "./project_info.json",
#     "project_name": "MyFirstProject",
#     "project_run_log_path": "./project_run.log"
# }
#
#
# checking integrity...
#
# [2023-05-08 09:15:29] [INFO] custom __init__.py for path 'RFC'
# [2023-05-08 09:15:29] [INFO] custom __init__.py for path 'RFC/tests'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/itemset'
# [2023-05-08 09:15:29] [INFO] custom __init__.py for path 'RFC/user'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/params'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/payload'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/proxies'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/url'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/user-agent'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/base'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/headers/referer'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/arguments/cookies'
# [2023-05-08 09:15:29] [INFO] system predefined __init__.py for path 'RFC/requestor/session/middleware'
#
# Done.
#
# compiling modules...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 19
#      16     project_config = get_project_config()
#      17     launch_project(project_config)
# ---> 19 initialize_project()
#
# Cell In[2], line 17, in initialize_project()
#      14     return project_config
#      16 project_config = get_project_config()
# ---> 17 launch_project(project_config)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/launch.py:31, in launch_project(project_config)
#      28 project_root = os.path.abspath(project_name)
#      29 project_config.project_root = project_root
# ---> 31 run_compile()
#      33 if os.path.exists(os.path.join(project_root, project_info_path)):
#      34     project_info = load_object(os.path.join(project_root, project_info_path))
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/compile.py:75, in run_compile()
#      73 check_integrity()
#      74 log('\n', pure_output=True, end='')
# ---> 75 setup()
#      76 switch_output_channel('compile_log', False)
#      77 log('\n', pure_output=True, end='')
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/compile.py:46, in setup()
#      44 result = {}
#      45 module_list = {}
# ---> 46 result['requestor'], _module_list = requestor.setup(**setup_settings.get('requestor', {}))
#      47 update_module_list(module_list, _module_list)
#      48 result['itemset'], _module_list = itemset.setup(**setup_settings.get('itemset', {}))
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/__init__.py:16, in setup(**kwargs)
#      14 if submodule_type == 'package':
#      15     submodule = import_submodule(submodule_name, __name__)
# ---> 16     result[submodule_name], _module_list = submodule.setup(**kwargs.get(submodule_name, {}))
#      17     module_list.update(_module_list)
#      18 elif submodule_name == module_name:
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/__init__.py:16, in setup(**kwargs)
#      14 if submodule_type == 'package':
#      15     submodule = import_submodule(submodule_name, __name__)
# ---> 16     result[submodule_name], _module_list = submodule.setup(**kwargs.get(submodule_name, {}))
#      17     module_list.update(_module_list)
#      18 elif submodule_name == module_name:
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/middleware/__init__.py:19, in setup(**kwargs)
#      17     module_list.update(_module_list)
#      18 elif submodule_name == module_name:
# ---> 19     submodule = import_submodule(submodule_name, __name__)
#      20     if 'init' in submodule.leaves:
#      21         result['options'] = {'init': (str(inspect.signature(submodule.leaves['init'][0])), submodule.leaves['init'][1])}
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/utils/structural_utils.py:59, in import_submodule(submodule, module_name)
#      57 if not submodule.startswith('.'):
#      58     submodule = '.' + submodule
# ---> 59 return importlib.import_module(submodule, module_name)
#
# File ~/Workspace/Applications/anaconda3/envs/share_py310/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Workspace/Datasets/Crawlers/TMP/workdir/RFC/requestor/session/middleware/middleware.py:4
#       1 from RFC.utils.structural_utils import leaf, get_leaves
#       2 from RFC.utils.exception_utils import ConditionOverflowError, ParamTypeError, ParamValueError
# ----> 4 from .MiddlewareConfig import MiddlewareConfig
#       5 from .MiddlewareConfigMyProxy import MiddlewareConfigMyProxy
#       6 from .Middleware import Middleware
#
# ModuleNotFoundError: No module named 'RFC.requestor.session.middleware.MiddlewareConfig'

# %%
def get_itemset():
    log('initializing itemset...\n', mode='info', note='Pipeline', from_module=__name__)
    def get_itemset_config():
        itemset_config = get_config('rawitemset')
        itemset_config = itemset_config(
            name='MyItemset',
            items=list(range(200000, 210000)),
            preprocess=None,
            attrs={
                'url': lambda i, x: f'https://www.pixiv.net/ajax/illust/{x}',
                'method': 'get',
                'name': lambda i, x: f'illust_{x}',
            },
            shuffle=True,
        )
        return itemset_config

    itemset_config = get_itemset_config()
    itemset = get_module(itemset_config)
    itemset.show()
    return itemset


itemset = get_itemset()
# Out:
# [2023-05-05 15:38:49] (Pipeline) [INFO] initializing itemset...
#
# RawItem(name='illust_200088', url='https://www.pixiv.net/ajax/illust/200088', payload={}, params={}, method='get')
# RawItem(name='illust_206234', url='https://www.pixiv.net/ajax/illust/206234', payload={}, params={}, method='get')
# RawItem(name='illust_205347', url='https://www.pixiv.net/ajax/illust/205347', payload={}, params={}, method='get')
# RawItem(name='illust_202174', url='https://www.pixiv.net/ajax/illust/202174', payload={}, params={}, method='get')
# RawItem(name='illust_203625', url='https://www.pixiv.net/ajax/illust/203625', payload={}, params={}, method='get')
# RawItem(name='illust_200338', url='https://www.pixiv.net/ajax/illust/200338', payload={}, params={}, method='get')
# RawItem(name='illust_201389', url='https://www.pixiv.net/ajax/illust/201389', payload={}, params={}, method='get')
# RawItem(name='illust_202551', url='https://www.pixiv.net/ajax/illust/202551', payload={}, params={}, method='get')
# RawItem(name='illust_204745', url='https://www.pixiv.net/ajax/illust/204745', payload={}, params={}, method='get')
# RawItem(name='illust_203103', url='https://www.pixiv.net/ajax/illust/203103', payload={}, params={}, method='get')

# %%
def get_requestor():
    log('initializing requestor...\n', mode='info', note='Pipeline', from_module=__name__)

    def get_arguments_config():
        arguments_config = get_config('arguments-noproxy')
        arguments_config = arguments_config(
            name='MyArguments',
            config={
                'cookies': {
                    'kwargs': {
                        'cookies': {
                            'PHPSESSID': '1234567890abcdef1234567890abcdef',
                            'device_token': '1234567890abcdef1234567890abcdef',
                        },
                        'ctype': dict,
                    },
                    'method': 'passin',
                },
            },
        )
        # arguments_config.print()
        return arguments_config

    def get_session_config():
        session_config = get_config('aiohttp')
        session_config = session_config(
            name='MySession',
            arguments_config=get_arguments_config(),
            total_timeout=20,
            connections=10,
            connections_per_host=10,
        )
        # session_config.print(include_sub=True)
        return session_config

    def get_requestor_config():
        requestor_config = get_config('requestor')
        requestor_config = requestor_config(
            name='MyRequestor',
            session_config=get_session_config(),
        )
        requestor_config.print(include_sub=True)
        return requestor_config

    requstor_config = get_requestor_config()
    requestor = get_module(requstor_config)
    return requestor


requestor = get_requestor()
# Out:
# [2023-05-05 15:40:09] (Pipeline) [INFO] initializing requestor...
#
# [2023-05-05 15:40:09] [INFO]
# RequestorConfig
# {
#     "name": "MyRequestor",
#     "session_config": {
#         "arguments_config": {
#             "config": {
#                 "cookies": {
#                     "kwargs": {
#                         "cookies": {
#                             "PHPSESSID": "1234567890abcdef1234567890abcdef",
#                             "device_token": "1234567890abcdef1234567890abcdef"
#                         },
#                         "ctype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "headers": {
#                     "base": {
#                         "kwargs": {
#                             "option": "default"
#                         },
#                         "method": "switch"
#                     },
#                     "kwargs": {},
#                     "referer": {
#                         "kwargs": {},
#                         "method": "from_url"
#                     },
#                     "user-agent": {
#                         "kwargs": {
#                             "type": "firefox"
#                         },
#                         "method": "random_fake"
#                     }
#                 },
#                 "kwargs": {},
#                 "params": {
#                     "kwargs": {
#                         "ptype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "payload": {
#                     "kwargs": {
#                         "ptype": "<class 'dict'>"
#                     },
#                     "method": "passin"
#                 },
#                 "proxies": {
#                     "kwargs": {},
#                     "method": "off"
#                 },
#                 "url": {
#                     "kwargs": {},
#                     "method": "passin"
#                 }
#             },
#             "name": "MyArguments"
#         },
#         "async_framework": "asyncio",
#         "connect_timeout": null,
#         "connections": 10,
#         "connections_per_host": 10,
#         "contiguous_failed_counts_threshold": null,
#         "framework": "aiohttp",
#         "name": "MySession",
#         "sock_connect_timeout": null,
#         "sock_read_timeout": null,
#         "total_timeout": 20,
#         "use_async": true,
#         "use_session": true
#     }
# }

# %%
def get_requestor():
    

    def get_session_config():
        ...

    def get_requestor_config():
        ...
    
    requestor_config = get_requestor_config()
    requestor_config.print()
    requestor = get_module(requestor_config)
    return requestor


requestor = get_requestor()

# %%
# Convert .ipynb to .py
import os

if __name__ == '__main__':
    os.system('jupyter nbconvert --to python <your_notebook_name>.ipynb')
